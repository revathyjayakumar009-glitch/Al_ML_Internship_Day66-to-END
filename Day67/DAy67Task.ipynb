# %% [markdown]
# # **Practical Task 1**
# Install the required libraries:

# %%
pip install PyPDF2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install chromadb
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sentence-transformers
# Out:
# ...
#    ---------------------------------------- 0.0/611.3 kB ? eta -:--:--
#    ---------------------------------- ----- 524.3/611.3 kB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 611.3/611.3 kB 2.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.6 MB 4.4 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.6/11.6 MB 3.8 MB/s eta 0:00:03
#    -------- ------------------------------- 2.4/11.6 MB 4.1 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.4/11.6 MB 4.2 MB/s eta 0:00:02
#    -------------- ------------------------- 4.2/11.6 MB 4.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.0/11.6 MB 4.1 MB/s eta 0:00:02
#    ------------------- -------------------- 5.8/11.6 MB 4.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.6/11.6 MB 4.1 MB/s eta 0:00:02
# ...

# %% [markdown]
# # **Practical Task 2**
# Read a PDF file using PyPDF2 and print its contents.

# %%
import PyPDF2

with open("Day 67-RAG.pdf", "rb") as file:
    reader = PyPDF2.PdfReader(file)

    for page in reader.pages:
        print(page.extract_text())
# Out:
#      AI/ML Internship – Day 67 Notes & Tasks
#   Module 9: Introduction to Retrieval -Augmented Generation (RAG) – Building a PDF
# Question Answering System
#
#      Part 1: Recap of Day 66
# Yesterday we learned:
#    What is RAG?
#    Knowledge Base
#    Embeddings
#    Vector Database
#    RAG Architecture
# Today we will learn:
# • How documents are prepared
# • Text Chunking
# • Embedding Generation
# • Vector Database
# • Complete PDF Question Answering Pipeline
#
#      Part 2: Problem Without RAG
# Suppose a company has:
# • Employee Handbook (250 Pages)
# • AI Internship Guide
# • HR Policy
# • Cyber Security Manual
# User asks:
# What is the internship duration?
# Without RAG:
#   AI may not know because these are private documents.
# With RAG:
#    AI searches the document and answers correctly.
#
#      Part 3: RAG Pipeline
# Upload PDF
#       │
#       ▼
# Extract Text
#       │
#       ▼
# Split into Chunks
#       │
#       ▼
# Create Embeddings
#       │
#       ▼
# ...

# %% [markdown]
# # Practical Task 3
# Create a sample document and manually divide it into 5 chunks.

# %% [raw]
# # Sample.txt
# Artificial Intelligence (AI) is a technology that enables computers
# to perform tasks that normally require human intelligence. AI is used
# in many areas such as healthcare, education, finance, and transportation.
#
# Machine Learning (ML) is a branch of Artificial Intelligence. It allows
# computers to learn patterns from data and make predictions or decisions
# without being explicitly programmed for every task.
#
# Deep Learning is a subset of Machine Learning that uses artificial
# neural networks with multiple layers. It is widely used in image
# recognition, speech recognition, and natural language processing.
#
# Natural Language Processing (NLP) is a field of AI that focuses on
# enabling computers to understand and process human language. Chatbots,
# language translation, and sentiment analysis are common NLP applications.
#
# Retrieval-Augmented Generation (RAG) combines information retrieval
# with generative AI. RAG retrieves relevant information from external
# documents and provides it to a language model to generate accurate
# answers.
#
# Step 2: Divide the Document into 5 Chunks
#
# For this practical task, we can manually divide the document into 5 chunks.
#
# Chunk 1 – Artificial Intelligence
# Artificial Intelligence (AI) is a technology that enables computers
# to perform tasks that normally require human intelligence. AI is used
# in many areas such as healthcare, education, finance, and transportation.
#
# Chunk 2 – Machine Learning
# Machine Learning (ML) is a branch of Artificial Intelligence. It allows
# computers to learn patterns from data and make predictions or decisions
# without being explicitly programmed for every task.
#
# Chunk 3 – Deep Learning
# Deep Learning is a subset of Machine Learning that uses artificial
# neural networks with multiple layers. It is widely used in image
# recognition, speech recognition, and natural language processing.
#
# Chunk 4 – Natural Language Processing
# Natural Language Processing (NLP) is a field of AI that focuses on
# enabling computers to understand and process human language. Chatbots,
# language translation, and sentiment analysis are common NLP applications.
#
# Chunk 5 – RAG
# Retrieval-Augmented Generation (RAG) combines information retrieval
# with generative AI. RAG retrieves relevant information from external
# documents and provides it to a language model to generate accurate
# answers.

# %% [markdown]
# # **Practical Task 4**
# Draw the complete RAG pipeline diagram.

# %%
from IPython.display import Image, display

display(Image(filename="a.png"))

# %% [markdown]
# # **Practical Task 5**
# Research the differences between: <br>
# • FAISS <br>
# • ChromaDB <br>
# • Pinecone  <br>
# Prepare a comparison table.

# %% [markdown]
# | Feature                   | **FAISS**                                 | **ChromaDB**                                          | **Pinecone**                        |
# | ------------------------- | ----------------------------------------- | ----------------------------------------------------- | ----------------------------------- |
# | Full name                 | Facebook AI Similarity Search             | Chroma                                                | Pinecone Vector Database            |
# | Type                      | Similarity-search library                 | Open-source vector database                           | Managed vector database             |
# | Developed by              | Meta AI                                   | Chroma                                                | Pinecone                            |
# | Open source               | Yes                                       | Yes                                                   | No, managed service                 |
# | Deployment                | Mainly local / self-managed               | Local, self-hosted, or cloud options                  | Cloud-managed                       |
# | Main purpose              | Fast similarity search over vectors       | Store and retrieve embeddings for AI/RAG applications | Production-scale vector search      |
# | Storage                   | Primarily indexes/vectors                 | Vectors, documents and metadata                       | Vectors/records and metadata        |
# | Ease of use               | Moderate                                  | Easy                                                  | Easy, but requires cloud setup      |
# | Scalability               | Depends on your infrastructure            | Suitable from development to deployed workloads       | Designed for large-scale production |
# | Internet required         | No for local use                          | No for local use                                      | Yes                                 |
# | Infrastructure management | User manages it                           | User-managed when self-hosted                         | Pinecone manages infrastructure     |
# | Best suited for           | Research, experiments, local applications | RAG projects, prototypes and applications             | Production AI applications          |
# | Cost                      | Free/open source                          | Open source; cloud options may have costs             | Usage-based cloud service           |
# | Example RAG use           | Local document search                     | College PDF chatbot                                   | Enterprise knowledge-base chatbot   |
