# %% [markdown]
# # **Practical Task 1**
# Install the Sentence Transformers library.

# %%
pip install sentence-transformers
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # **Practical Task 2**
# Load the all-MiniLM-L6-v2 model.

# %%
from sentence_transformers import SentenceTransformer

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")

print("Model loaded successfully!")
# Out:
# ...
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# C:\Users\DELL\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:141: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\DELL\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %% [markdown]
# # **Practical Task 3**
# Generate embeddings for these sentences: <br>
# • Artificial Intelligence<br>
# • Machine Learning<br>
# • Deep Learning<br>
# • Python Programming<br>

# %%
# Define sentences
sentences = [
    "Artificial Intelligence",
    "Machine Learning",
    "Deep Learning",
    "Python Programming"
]

# Generate embeddings
embeddings = model.encode(sentences)

# Display embeddings
for sentence, embedding in zip(sentences, embeddings):
    print("\nSentence:", sentence)
    print("Embedding:", embedding)
# Out:
# Sentence: Artificial Intelligence
# Embedding: [-2.43510120e-02  1.67067088e-02  3.77205014e-02 -9.16333031e-03
#  -3.05845272e-02 -1.70570929e-02  7.42097944e-02  4.57434654e-02
#  -9.39858612e-03  9.89999902e-03 -5.70727326e-03  7.58130616e-03
#   3.95797119e-02  1.52103342e-02 -8.32181126e-02  1.93441566e-02
#  -2.19868142e-02 -3.32064144e-02 -1.81014150e-01 -1.30236059e-01
#  -2.25592079e-03  1.33974524e-02 -2.42932551e-02 -3.69969457e-02
#   2.02795444e-03  8.56798589e-02  4.72735288e-03 -3.41750355e-03
#  -6.03478076e-03 -1.15787193e-01  6.68601915e-02 -1.86577197e-02
#   8.78416598e-02 -7.42435083e-03 -9.35673714e-02  6.14009537e-02
#  -8.11372399e-02  1.22458339e-02  3.97397056e-02 -2.58960784e-03
#  -4.66313623e-02 -8.17789659e-02  3.95028926e-02  1.54695576e-02
#   4.36928794e-02  1.03639200e-01 -5.84595725e-02  3.67366076e-02
#  -5.27095571e-02  4.05691899e-02 -1.25884533e-01  6.46111369e-03
#  -3.58352475e-02 -1.00228852e-02 -2.38814056e-02  4.59325314e-02
# ...

# %% [markdown]
# # **Practical Task 4**
# Research three popular embedding models and compare their features.

# %% [markdown]
# | Feature               | **Word2Vec**                | **GloVe**                      | **all-MiniLM-L6-v2**                  |
# | --------------------- | --------------------------- | ------------------------------ | ------------------------------------- |
# | Developed by          | Google                      | Stanford researchers           | Sentence Transformers                 |
# | Introduced            | 2013                        | 2014                           | 2020                                  |
# | Type                  | Word embedding              | Word embedding                 | Sentence embedding                    |
# | Main purpose          | Represent individual words  | Represent individual words     | Represent sentences/text              |
# | Context understanding | Limited                     | Limited                        | Better semantic understanding         |
# | Training approach     | Predicts words from context | Uses global word co-occurrence | Transformer-based model               |
# | Output                | Vector per word             | Vector per word                | 384-dimensional vector per sentence   |
# | Suitable for          | Word similarity, NLP        | Word similarity, NLP           | Semantic search, RAG, text similarity |
# | Modern RAG usage      | Limited                     | Limited                        | **Very useful**                       |
# | Example               | `"python"` → vector         | `"python"` → vector            | `"I love Python"` → vector            |
